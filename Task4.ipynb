# %%
def plot_distribution_fixed(data, columns):
    num_cols = len(columns)
    cols_per_row = 4  # Set the number of plots per row
    num_rows = (num_cols + cols_per_row - 1) // cols_per_row  # Calculate required rows

    plt.figure(figsize=(15, num_rows * 4))
    for i, col in enumerate(columns, 1):
        plt.subplot(num_rows, cols_per_row, i)
        sns.histplot(data[col], kde=True, bins=20, color='skyblue')
        plt.title(f'Distribution of {col}')
    plt.tight_layout()
    plt.show()

# Plot distributions again with the fixed grid size
plot_distribution_fixed(df, numeric_columns)

# Boxplot to identify outliers
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[numeric_columns], palette="Set2")
plt.title('Boxplot to Identify Outliers')
plt.show()

# Correlation Heatmap
plt.figure(figsize=(12, 8))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
